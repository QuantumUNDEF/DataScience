# %%
import pandas as pd
#importing pandas

# %%
#reading dataframe
df = pd.read_csv("AB_NYC_2019.csv")
df1 = df.copy()
# print(df1)

# %%
df1.duplicated().sum()
# this will return a number of rows that are exactly duplicate
# Out:
# np.int64(11)

# %%
df.shape
# Out:
# (48906, 16)

# %%
df1.shape
# Out:
# (48906, 16)

# %%
df1[df1.duplicated()] 
# the inner snippet will return a boolean mask
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48901     True
# 48902     True
# 48903     True
# 48904     True
# 48905     True
# Length: 48906, dtype: bool

# %%
df1[df1.duplicated(keep = 'first')]
# by default keep is assign by First
# this will return a boolen mask for first 11 duplicate rows
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df1[df1.duplicated(keep = 'last')]
# # this will return a boolen mask for "last" 11 duplicate rows
# Out:
#       id                                              name  host_id  \
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 14  6090                     West Village Nest - Superhost    11975
# 15  6848                  Only 2 stops to Manhattan studio    15991
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 5           Chris           Manhattan         Murray Hill  40.74767
# ...

# %%
df1[df1.duplicated(keep = False)]
# this will not keep anything and resturn the all duplicated rows 11 + 11  = 22
# Out:
#          id                                              name  host_id  \
# 5      5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6      5121                                   BlissArtsSpace!     7356
# 7      5178                  Large Furnished Room Near B'way      8967
# 8      5203                Cozy Clean Guest Room - Family Apt     7490
# 9      5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10     5295                  Beautiful 1br on Upper West Side     7702
# 11     5441                   Central Manhattan/near Broadway     7989
# 12     5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 13     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 14     6090                     West Village Nest - Superhost    11975
# 15     6848                  Only 2 stops to Manhattan studio    15991
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# ...

# %%
df1[df1.duplicated(keep = False)].shape
# Out:
# (22, 16)

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.drop_duplicates(inplace = True)

# %%
print(df1.shape)
print(df.shape)
# Out:
# (48895, 16)
# (48906, 16)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
cities = ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix','Los Angeles', 'Chicago']
rankings = [1, 2, 3, 4, 5,6,7]
scores = [9.8, 9.5, 9.2, 8.7, 8.5, 8.2, 8.1]
#creating a Dictionary from Lists
data = {'City': cities, 'Ranking': rankings, 'Score': scores}
# Creating dataframe or matrix from the dictionary
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#           City  Ranking  Score
# 0     New York        1    9.8
# 1  Los Angeles        2    9.5
# 2      Chicago        3    9.2
# 3      Houston        4    8.7
# 4      Phoenix        5    8.5
# 5  Los Angeles        6    8.2
# 6      Chicago        7    8.1

# %%
df2.duplicated().sum() #this will return 0 becoz it return True when the "Entire row is exatly same"
# so how do we check for the let suppose City column
# Out:
# np.int64(0)

# %%
df2.duplicated("City").sum()
# Out:
# np.int64(2)

# %%
from IPython.display import display

display(df2.drop_duplicates("City", keep = "first"))
display(df2.drop_duplicates("City", keep = "last"))
display(df2.drop_duplicates("City", keep = False))
# Out:
#           City  Ranking  Score
# 0     New York        1    9.8
# 1  Los Angeles        2    9.5
# 2      Chicago        3    9.2
# 3      Houston        4    8.7
# 4      Phoenix        5    8.5
#           City  Ranking  Score
# 0     New York        1    9.8
# 3      Houston        4    8.7
# 4      Phoenix        5    8.5
# 5  Los Angeles        6    8.2
# 6      Chicago        7    8.1
#        City  Ranking  Score
# 0  New York        1    9.8
# 3   Houston        4    8.7
# 4   Phoenix        5    8.5
